# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
# from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
# anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
# deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
# groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
# if anthropic_api_key:
#     print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
# else:
#     print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

# if deepseek_api_key:
#     print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
# else:
#     print("DeepSeek API Key not set (and this is optional)")

# if groq_api_key:
#     print(f"Groq API Key exists and begins {groq_api_key[:4]}")
# else:
#     print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Google API Key exists and begins AI

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence."
request += "Answer only with the question, no explanation. In just 50 words or less."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence.Answer only with the question, no explanation. In just 50 words or less.'}]

# %%
openai = OpenAI()
res = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

question = res.choices[0].message.content
print(question)
# Out:
# If a person has a set of beliefs that contradict observable facts but remains unwavering in their conviction, how can one effectively engage in a dialogue to encourage critical thinking, without resorting to confrontation or dismissiveness, while still respecting their perspective?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %%
# The API we know well

model_name = "gpt-4o-mini"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Engaging in dialogue with someone who holds beliefs that contradict observable facts requires patience, empathy, and strategic communication. Here are several approaches to facilitate an effective and respectful conversation:
#
# 1. **Establish a Rapport**: Begin by creating a comfortable environment. Show genuine interest in the person's views and experiences, which can help build trust.
#
# 2. **Active Listening**: Practice active listening by acknowledging their beliefs without judgment. Paraphrasing or summarizing what they say can demonstrate that you value their perspective.
#
# 3. **Ask Open-Ended Questions**: Encourage critical thinking by asking open-ended questions that prompt reflection. For example, "What led you to that conclusion?" or "How do you feel that aligns with what we observe in reality?"
#
# 4. **Share Personal Experiences**: Instead of directly challenging their beliefs, share your own experiences or observations that highlight the discrepancy in a personal way. This can make the conversation feel less confrontational.
#
# 5. **Introduce Evidence Gently**: Present evidence or facts in a non-threatening manner. You can frame it as "I found this information interesting; what do you think about it?" This way, it appears more like sharing rather than arguing.
#
# 6. **Focus on Common Goals**: Identify shared values or concerns and steer the conversation towards those. This can create common ground and make the discussion feel collaborative rather than oppositional.
#
# 7. **Encourage Exploration**: Suggest exploring the topic further together. Propose reading articles, watching documentaries, or attending lectures to gather more information. This can shift the focus from a debate to a shared quest for understanding.
#
# 8. **Practice Patience and Respect**: Recognize that changing deeply held beliefs takes time. Be patient and consistently approach the conversation with respect for their perspective, even if you disagree.
#
# 9. **Be Open to Learning**: Display your own willingness to consider other viewpoints and learn, which can encourage reciprocation. Acknowledging what you find valuable in their perspective can foster a more open dialogue.
#
# 10. **Know When to Step Back**: If the conversation becomes too heated or unproductive, it might be best to pause and revisit the topic later. Maintaining a positive relationship is often more important than winning an argument.
#
# By using these techniques, you can facilitate a constructive dialogue that encourages critical thinking and allows for a more respectful exchange of differing viewpoints.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-3-7-sonnet-latest"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.0-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "llama-3.3-70b-versatile"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "phi4-mini"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Engaging someone whose belief system is rooted deeply against empirical evidence presents both challenges and opportunities for encouraging open-mindedness. Here’s an approach that balances respect with the goal of fostering healthy skepticism:
#
# 1. **Listen Attentively**: Demonstrate genuine interest in understanding where they are coming from, without judgment or interruption.
#
# 2. **Ask Open-Ended Questions**: Encourage them to elaborate on their beliefs by asking questions like “What leads you to this conclusion?” This can help others articulate reasons that might be flawed and open up discussions about the basis of those conclusions.
#
#
# 3. **Seek Common Ground**: Identify any aspects within which there may already exist commonality, even if only partially shared values or observations.
#
# 4. **Encourage Questioning Their Own Arguments (Socratic Method)**: Invite them to consider questions that naturally arise from their assertions; this method is non-confrontational and guides someone toward self-reflection.
#
#
# 5. **Present Alternative Explanations**: If there's a basis in observable facts, gently introduce the other side of evidence using language that's inclusive rather than dismissive (“It's interesting you see it like this — have I shared something new that might explain differently?”).
#
# 6. **Focus on Empathy and Shared Experience (Narrative Persuasion)**: Humans are naturally drawn to narratives; sharing stories from a scientific perspective can make concepts more relatable, helping bridge the gap without being confrontational.
#
# 7. **Reinforce Positive Interactions**: When they express curiosity or willingness for discussion in any direction that isn’t combative and dismissive already — even if still holding contradictory beliefs somewhere else – reinforce this behavior with positive feedback.
#
#
# 8. **Be Patient (Time Factor)**: Recognize learning, especially involving deeply-held convictions against empirical evidence is a process; change rarely happens overnight.
#
# 9. **Maintain Open-Ended Dialogue**: Avoid ending conversations abruptly or making definitive assessments of their character based on belief divergence—keep the lines open for further discussion.
#
#
# 10. **Consider Their Motivations and Worldview (Relational Empathy)**: Understand that beyond contradicting facts, there can be complex reasons why someone adheres to certain beliefs; acknowledging this complexity helps maintain respectful communication even when disagreements arise.
#
# Remember it's often not about 'changing someone's mind' but rather cultivating an environment where ideas are openly exchanged with respect for individual thought processes and personal boundaries.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-4o-mini', 'gemini-2.0-flash', 'phi4-mini']
# ['Engaging in dialogue with someone who holds beliefs that contradict observable facts requires patience, empathy, and strategic communication. Here are several approaches to facilitate an effective and respectful conversation:\n\n1. **Establish a Rapport**: Begin by creating a comfortable environment. Show genuine interest in the person\'s views and experiences, which can help build trust.\n\n2. **Active Listening**: Practice active listening by acknowledging their beliefs without judgment. Paraphrasing or summarizing what they say can demonstrate that you value their perspective.\n\n3. **Ask Open-Ended Questions**: Encourage critical thinking by asking open-ended questions that prompt reflection. For example, "What led you to that conclusion?" or "How do you feel that aligns with what we observe in reality?"\n\n4. **Share Personal Experiences**: Instead of directly challenging their beliefs, share your own experiences or observations that highlight the discrepancy in a personal way. This can make the conversation feel less confrontational.\n\n5. **Introduce Evidence Gently**: Present evidence or facts in a non-threatening manner. You can frame it as "I found this information interesting; what do you think about it?" This way, it appears more like sharing rather than arguing.\n\n6. **Focus on Common Goals**: Identify shared values or concerns and steer the conversation towards those. This can create common ground and make the discussion feel collaborative rather than oppositional.\n\n7. **Encourage Exploration**: Suggest exploring the topic further together. Propose reading articles, watching documentaries, or attending lectures to gather more information. This can shift the focus from a debate to a shared quest for understanding.\n\n8. **Practice Patience and Respect**: Recognize that changing deeply held beliefs takes time. Be patient and consistently approach the conversation with respect for their perspective, even if you disagree.\n\n9. **Be Open to Learning**: Display your own willingness to consider other viewpoints and learn, which can encourage reciprocation. Acknowledging what you find valuable in their perspective can foster a more open dialogue.\n\n10. **Know When to Step Back**: If the conversation becomes too heated or unproductive, it might be best to pause and revisit the topic later. Maintaining a positive relationship is often more important than winning an argument.\n\nBy using these techniques, you can facilitate a constructive dialogue that encourages critical thinking and allows for a more respectful exchange of differing viewpoints.', 'Engaging someone with deeply held beliefs that contradict observable facts is a delicate process. It\'s less about directly changing their mind and more about planting seeds of doubt and encouraging self-reflection. Here\'s a breakdown of strategies:\n\n**1. Building Rapport and Establishing Trust:**\n\n*   **Listen empathetically:**  Before challenging anything, genuinely listen to their perspective. Understand the *why* behind their belief. Ask open-ended questions like, "What led you to believe this?" or "How has this belief shaped your life?"  Show you are interested in *understanding* them, not just *correcting* them.\n*   **Find common ground:**  Identify areas of agreement, even if they\'re tangential.  For example, if someone believes in a conspiracy theory about a specific government agency, you might agree that government transparency is important. Building on shared values creates a foundation for dialogue.\n*   **Use a calm and respectful tone:**  Avoid sarcasm, condescension, or aggressive language.  Your goal is to engage in a conversation, not win an argument.  Mirror their communication style to a degree to establish rapport.\n*   **Acknowledge their intelligence and sincerity:**  Even if you disagree, avoid implying they are stupid or malicious. Say things like, "I understand you\'ve put a lot of thought into this," or "I appreciate you sharing your persp ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-4o-mini
#
# Engaging in dialogue with someone who holds beliefs that contradict observable facts requires patience, empathy, and strategic communication. Here are several approaches to facilitate an effective and respectful conversation:
#
# 1. **Establish a Rapport**: Begin by creating a comfortable environment. Show genuine interest in the person's views and experiences, which can help build trust.
#
# 2. **Active Listening**: Practice active listening by acknowledging their beliefs without judgment. Paraphrasing or summarizing what they say can demonstrate that you value their perspective.
#
# 3. **Ask Open-Ended Questions**: Encourage critical thinking by asking open-ended questions that prompt reflection. For example, "What led you to that conclusion?" or "How do you feel that aligns with what we observe in reality?"
#
# 4. **Share Personal Experiences**: Instead of directly challenging their beliefs, share your own experiences or observations that highlight the discrepancy in a personal way. This can make the conversation feel less confrontational.
#
# 5. **Introduce Evidence Gently**: Present evidence or facts in a non-threatening manner. You can frame it as "I found this information interesting; what do you think about it?" This way, it appears more like sharing rather than arguing.
#
# 6. **Focus on Common Goals**: Identify shared values or concerns and steer the conversation towards those. This can create common ground and make the discussion feel collaborative rather than oppositional.
#
# 7. **Encourage Exploration**: Suggest exploring the topic further together. Propose reading articles, watching documentaries, or attending lectures to gather more information. This can shift the focus from a debate to a shared quest for understanding.
#
# 8. **Practice Patience and Respect**: Recognize that changing deeply held beliefs takes time. Be patient and consistently approach the conversation with respect for their perspective, even if you disagree.
#
# 9. **Be Open to Learning**: Display your own willingness to consider other viewpoints and learn, which can encourage reciprocation. Acknowledging what you find valuable in their perspective can foster a more open dialogue.
#
# 10. **Know When to Step Back**: If the conversation becomes too heated or unproductive, it might be best to pause and revisit the topic later. Maintaining a positive relationship is often more important than winning an argument.
#
# By using these techniques, you can facilitate a constructive dialogue that encourages critical thinking and allows for a more respectful exchange of differing viewpoints.
# Competitor: gemini-2.0-flash
#
# Engaging someone with deeply held beliefs that contradict observable facts is a delicate process. It's less about directly changing their mind and more about planting seeds of doubt and encouraging self-reflection. Here's a breakdown of strategies:
#
# **1. Building Rapport and Establishing Trust:**
#
# *   **Listen empathetically:**  Before challenging anything, genuinely listen to their perspective. Understand the *why* behind their belief. Ask open-ended questions like, "What led you to believe this?" or "How has this belief shaped your life?"  Show you are interested in *understanding* them, not just *correcting* them.
# *   **Find common ground:**  Identify areas of agreement, even if they're tangential.  For example, if someone believes in a conspiracy theory about a specific government agency, you might agree that government transparency is important. Building on shared values creates a foundation for dialogue.
# *   **Use a calm and respectful tone:**  Avoid sarcasm, condescension, or aggressive language.  Your goal is to engage in a conversation, not win an argument.  Mirror their communication style to a degree to establish rapport.
# *   **Acknowledge their intelligence and sincerity:**  Even if you disagree, avoid implying they are stupid or malicious. Say things like, "I understand you've put a lot of thought into this," or "I appreciate you sharing your perspective."
#
# **2.  Gentle Questioning and Promoting Self-Reflection:**
#
# *   **Socratic questioning:**  Instead of directly contradicting their beliefs, ask questions that encourage them to think critically about their own reasoning.  Focus on the *process* of their thinking, not just the *conclusion*.  Examples:
#     *   "What evidence do you find most convincing?"
#     *   "How did you come to believe this?"
#     *   "What would it take for you to reconsider your position?"
#     *   "Are there any alternative explanations for this?"
#     *   "How reliable do you consider your sources to be?"
# *   **Highlight inconsistencies within their own belief system:**  Sometimes, people hold beliefs that contradict each other. Gently point out these inconsistencies by asking clarifying questions.  Avoid saying "You're contradicting yourself!" Instead, try, "I'm a little confused, could you help me understand how these two ideas fit together?"
# *   **Focus on verifiable facts, not opinions:**  Instead of debating subjective interpretations, direct the conversation to facts that are easily verifiable.  For example, if someone denies climate change, you could discuss objectively measured temperature increases and rising sea levels.
# *   **Use "I" statements:**  Frame your concerns as personal perspectives rather than universal truths.  For example, instead of saying "That's wrong," try "I've always understood it differently.  I've read that..."  This reduces defensiveness.
# *   **Present alternative perspectives indirectly:**  Instead of saying, "Here's why you're wrong," you could say, "I was reading an article the other day that presented a different viewpoint. It said..."
# *   **Highlight the potential consequences of holding the belief:**  Gently explore the practical implications of their belief.  For example, "How does this belief affect your decision-making in [relevant area]?" or "Are there any downsides to holding this belief?"
#
# **3.  Providing Information and Resources Carefully:**
#
# *   **Offer information neutrally:**  Instead of lecturing, provide resources (articles, studies, reputable websites) without explicitly endorsing them.  Let them come to their own conclusions.  "I came across this article the other day that you might find interesting."
# *   **Focus on the source's credibility:**  If you're sharing information, emphasize the source's reputation for accuracy and impartiality. Explain why the source is considered trustworthy. Avoid sources known for bias or conspiracy theories.
# *   **Be prepared to be wrong:**  Be open to the possibility that *you* might be mistaken.  This shows humility and encourages reciprocal open-mindedness.  "I might be misunderstanding this. Can you explain...?"
#
# **4.  Managing Expectations and Avoiding Confrontation:**
#
# *   **Don't expect immediate change:**  Changing deeply held beliefs takes time and often requires a significant emotional shift.  Your goal is to plant seeds, not perform surgery.
# *   **Accept that you may not change their mind:**  Sometimes, people are simply unwilling to change their perspective.  That's okay.  Focus on maintaining a respectful relationship.
# *   **Know when to disengage:**  If the conversation becomes heated or unproductive, politely disengage.  "I appreciate you sharing your thoughts.  Maybe we can revisit this another time."  It's better to end the conversation amicably than to damage the relationship.
# *   **Focus on the process, not the outcome:**  The goal is to encourage critical thinking, not necessarily to win the argument.  Even if they don't change their mind, you may have encouraged them to think more critically about their beliefs in the future.
#
# **Important Considerations:**
#
# *   **Motivation:**  Why do you want to engage this person? Is it truly to help them, or to prove them wrong? Your motivation will influence your approach and their receptiveness.
# *   **The topic:** Some topics are more sensitive than others (politics, religion).  Approach these with extra caution and sensitivity.
# *   **The relationship:** The closer your relationship, the more leeway you have, but also the more potential for damaging the relationship.
# *   **Their personality:**  Some people are more open to new ideas than others.  Adapt your approach accordingly.
#
# By focusing on empathy, gentle questioning, and providing information in a neutral way, you can encourage critical thinking without resorting to confrontation or dismissiveness, while still respecting their perspective.  It's a long game, and success is measured in small steps.
#
# Competitor: phi4-mini
#
# Engaging someone whose belief system is rooted deeply against empirical evidence presents both challenges and opportunities for encouraging open-mindedness. Here’s an approach that balances respect with the goal of fostering healthy skepticism:
#
# 1. **Listen Attentively**: Demonstrate genuine interest in understanding where they are coming from, without judgment or interruption.
#
# 2. **Ask Open-Ended Questions**: Encourage them to elaborate on their beliefs by asking questions like “What leads you to this conclusion?” This can help others articulate reasons that might be flawed and open up discussions about the basis of those conclusions.
#
#
# 3. **Seek Common Ground**: Identify any aspects within which there may already exist commonality, even if only partially shared values or observations.
#
# 4. **Encourage Questioning Their Own Arguments (Socratic Method)**: Invite them to consider questions that naturally arise from their assertions; this method is non-confrontational and guides someone toward self-reflection.
#
#
# 5. **Present Alternative Explanations**: If there's a basis in observable facts, gently introduce the other side of evidence using language that's inclusive rather than dismissive (“It's interesting you see it like this — have I shared something new that might explain differently?”).
#
# 6. **Focus on Empathy and Shared Experience (Narrative Persuasion)**: Humans are naturally drawn to narratives; sharing stories from a scientific perspective can make concepts more relatable, helping bridge the gap without being confrontational.
#
# 7. **Reinforce Positive Interactions**: When they express curiosity or willingness for discussion in any direction that isn’t combative and dismissive already — even if still holding contradictory beliefs somewhere else – reinforce this behavior with positive feedback.
#
#
# 8. **Be Patient (Time Factor)**: Recognize learning, especially involving deeply-held convictions against empirical evidence is a process; change rarely happens overnight.
#
# 9. **Maintain Open-Ended Dialogue**: Avoid ending conversations abruptly or making definitive assessments of their character based on belief divergence—keep the lines open for further discussion.
#
#
# 10. **Consider Their Motivations and Worldview (Relational Empathy)**: Understand that beyond contradicting facts, there can be complex reasons why someone adheres to certain beliefs; acknowledging this complexity helps maintain respectful communication even when disagreements arise.
#
# Remember it's often not about 'changing someone's mind' but rather cultivating an environment where ideas are openly exchanged with respect for individual thought processes and personal boundaries.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Engaging in dialogue with someone who holds beliefs that contradict observable facts requires patience, empathy, and strategic communication. Here are several approaches to facilitate an effective and respectful conversation:
#
# 1. **Establish a Rapport**: Begin by creating a comfortable environment. Show genuine interest in the person's views and experiences, which can help build trust.
#
# 2. **Active Listening**: Practice active listening by acknowledging their beliefs without judgment. Paraphrasing or summarizing what they say can demonstrate that you value their perspective.
#
# 3. **Ask Open-Ended Questions**: Encourage critical thinking by asking open-ended questions that prompt reflection. For example, "What led you to that conclusion?" or "How do you feel that aligns with what we observe in reality?"
#
# 4. **Share Personal Experiences**: Instead of directly challenging their beliefs, share your own experiences or observations that highlight the discrepancy in a personal way. This can make the conversation feel less confrontational.
#
# 5. **Introduce Evidence Gently**: Present evidence or facts in a non-threatening manner. You can frame it as "I found this information interesting; what do you think about it?" This way, it appears more like sharing rather than arguing.
#
# 6. **Focus on Common Goals**: Identify shared values or concerns and steer the conversation towards those. This can create common ground and make the discussion feel collaborative rather than oppositional.
#
# 7. **Encourage Exploration**: Suggest exploring the topic further together. Propose reading articles, watching documentaries, or attending lectures to gather more information. This can shift the focus from a debate to a shared quest for understanding.
#
# 8. **Practice Patience and Respect**: Recognize that changing deeply held beliefs takes time. Be patient and consistently approach the conversation with respect for their perspective, even if you disagree.
#
# 9. **Be Open to Learning**: Display your own willingness to consider other viewpoints and learn, which can encourage reciprocation. Acknowledging what you find valuable in their perspective can foster a more open dialogue.
#
# 10. **Know When to Step Back**: If the conversation becomes too heated or unproductive, it might be best to pause and revisit the topic later. Maintaining a positive relationship is often more important than winning an argument.
#
# By using these techniques, you can facilitate a constructive dialogue that encourages critical thinking and allows for a more respectful exchange of differing viewpoints.
#
# # Response from competitor 2
#
# Engaging someone with deeply held beliefs that contradict observable facts is a delicate process. It's less about directly changing their mind and more about planting seeds of doubt and encouraging self-reflection. Here's a breakdown of strategies:
#
# **1. Building Rapport and Establishing Trust:**
#
# *   **Listen empathetically:**  Before challenging anything, genuinely listen to their perspective. Understand the *why* behind their belief. Ask open-ended questions like, "What led you to believe this?" or "How has this belief shaped your life?"  Show you are interested in *understanding* them, not just *correcting* them.
# *   **Find common ground:**  Identify areas of agreement, even if they're tangential.  For example, if someone believes in a conspiracy theory about a specific government agency, you might agree that government transparency is important. Building on shared values creates a foundation for dialogue.
# *   **Use a calm and respectful tone:**  Avoid sarcasm, condescension, or aggressive language.  Your goal is to engage in a conversation, not win an argument.  Mirror their communication style to a degree to establish rapport.
# *   **Acknowledge their intelligence and sincerity:**  Even if you disagree, avoid implying they are stupid or malicious. Say things like, "I understand you've put a lot of thought into this," or "I appreciate you sharing your perspective."
#
# **2.  Gentle Questioning and Promoting Self-Reflection:**
#
# *   **Socratic questioning:**  Instead of directly contradicting their beliefs, ask questions that encourage them to think critically about their own reasoning.  Focus on the *process* of their thinking, not just the *conclusion*.  Examples:
#     *   "What evidence do you find most convincing?"
#     *   "How did you come to believe this?"
#     *   "What would it take for you to reconsider your position?"
#     *   "Are there any alternative explanations for this?"
#     *   "How reliable do you consider your sources to be?"
# *   **Highlight inconsistencies within their own belief system:**  Sometimes, people hold beliefs that contradict each other. Gently point out these inconsistencies by asking clarifying questions.  Avoid saying "You're contradicting yourself!" Instead, try, "I'm a little confused, could you help me understand how these two ideas fit together?"
# *   **Focus on verifiable facts, not opinions:**  Instead of debating subjective interpretations, direct the conversation to facts that are easily verifiable.  For example, if someone denies climate change, you could discuss objectively measured temperature increases and rising sea levels.
# *   **Use "I" statements:**  Frame your concerns as personal perspectives rather than universal truths.  For example, instead of saying "That's wrong," try "I've always understood it differently.  I've read that..."  This reduces defensiveness.
# *   **Present alternative perspectives indirectly:**  Instead of saying, "Here's why you're wrong," you could say, "I was reading an article the other day that presented a different viewpoint. It said..."
# *   **Highlight the potential consequences of holding the belief:**  Gently explore the practical implications of their belief.  For example, "How does this belief affect your decision-making in [relevant area]?" or "Are there any downsides to holding this belief?"
#
# **3.  Providing Information and Resources Carefully:**
#
# *   **Offer information neutrally:**  Instead of lecturing, provide resources (articles, studies, reputable websites) without explicitly endorsing them.  Let them come to their own conclusions.  "I came across this article the other day that you might find interesting."
# *   **Focus on the source's credibility:**  If you're sharing information, emphasize the source's reputation for accuracy and impartiality. Explain why the source is considered trustworthy. Avoid sources known for bias or conspiracy theories.
# *   **Be prepared to be wrong:**  Be open to the possibility that *you* might be mistaken.  This shows humility and encourages reciprocal open-mindedness.  "I might be misunderstanding this. Can you explain...?"
#
# **4.  Managing Expectations and Avoiding Confrontation:**
#
# *   **Don't expect immediate change:**  Changing deeply held beliefs takes time and often requires a significant emotional shift.  Your goal is to plant seeds, not perform surgery.
# *   **Accept that you may not change their mind:**  Sometimes, people are simply unwilling to change their perspective.  That's okay.  Focus on maintaining a respectful relationship.
# *   **Know when to disengage:**  If the conversation becomes heated or unproductive, politely disengage.  "I appreciate you sharing your thoughts.  Maybe we can revisit this another time."  It's better to end the conversation amicably than to damage the relationship.
# *   **Focus on the process, not the outcome:**  The goal is to encourage critical thinking, not necessarily to win the argument.  Even if they don't change their mind, you may have encouraged them to think more critically about their beliefs in the future.
#
# **Important Considerations:**
#
# *   **Motivation:**  Why do you want to engage this person? Is it truly to help them, or to prove them wrong? Your motivation will influence your approach and their receptiveness.
# *   **The topic:** Some topics are more sensitive than others (politics, religion).  Approach these with extra caution and sensitivity.
# *   **The relationship:** The closer your relationship, the more leeway you have, but also the more potential for damaging the relationship.
# *   **Their personality:**  Some people are more open to new ideas than others.  Adapt your approach accordingly.
#
# By focusing on empathy, gentle questioning, and providing information in a neutral way, you can encourage critical thinking without resorting to confrontation or dismissiveness, while still respecting their perspective.  It's a long game, and success is measured in small steps.
#
#
# # Response from competitor 3
#
# Engaging someone whose belief system is rooted deeply against empirical evidence presents both challenges and opportunities for encouraging open-mindedness. Here’s an approach that balances respect with the goal of fostering healthy skepticism:
#
# 1. **Listen Attentively**: Demonstrate genuine interest in understanding where they are coming from, without judgment or interruption.
#
# 2. **Ask Open-Ended Questions**: Encourage them to elaborate on their beliefs by asking questions like “What leads you to this conclusion?” This can help others articulate reasons that might be flawed and open up discussions about the basis of those conclusions.
#
#
# 3. **Seek Common Ground**: Identify any aspects within which there may already exist commonality, even if only partially shared values or observations.
#
# 4. **Encourage Questioning Their Own Arguments (Socratic Method)**: Invite them to consider questions that naturally arise from their assertions; this method is non-confrontational and guides someone toward self-reflection.
#
#
# 5. **Present Alternative Explanations**: If there's a basis in observable facts, gently introduce the other side of evidence using language that's inclusive rather than dismissive (“It's interesting you see it like this — have I shared something new that might explain differently?”).
#
# 6. **Focus on Empathy and Shared Experience (Narrative Persuasion)**: Humans are naturally drawn to narratives; sharing stories from a scientific perspective can make concepts more relatable, helping bridge the gap without being confrontational.
#
# 7. **Reinforce Positive Interactions**: When they express curiosity or willingness for discussion in any direction that isn’t combative and dismissive already — even if still holding contradictory beliefs somewhere else – reinforce this behavior with positive feedback.
#
#
# 8. **Be Patient (Time Factor)**: Recognize learning, especially involving deeply-held convictions against empirical evidence is a process; change rarely happens overnight.
#
# 9. **Maintain Open-Ended Dialogue**: Avoid ending conversations abruptly or making definitive assessments of their character based on belief divergence—keep the lines open for further discussion.
#
#
# 10. **Consider Their Motivations and Worldview (Relational Empathy)**: Understand that beyond contradicting facts, there can be complex reasons why someone adheres to certain beliefs; acknowledging this complexity helps maintain respectful communication even when disagreements arise.
#
# Remember it's often not about 'changing someone's mind' but rather cultivating an environment where ideas are openly exchanged with respect for individual thought processes and personal boundaries.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 3 competitors.
# Each model has been given this question:
#
# If a person has a set of beliefs that contradict observable facts but remains unwavering in their conviction, how can one effectively engage in a dialogue to encourage critical thinking, without resorting to confrontation or dismissiveness, while still respecting their perspective?
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Engaging in dialogue with someone who holds beliefs that contradict observable facts requires patience, empathy, and strategic communication. Here are several approaches to facilitate an effective and respectful conversation:
#
# 1. **Establish a Rapport**: Begin by creating a comfortable environment. Show genuine interest in the person's views and experiences, which can help build trust.
#
# 2. **Active Listening**: Practice active listening by acknowledging their beliefs without judgment. Paraphrasing or summarizing what they say can demonstrate that you value their perspective.
#
# 3. **Ask Open-Ended Questions**: Encourage critical thinking by asking open-ended questions that prompt reflection. For example, "What led you to that conclusion?" or "How do you feel that aligns with what we observe in reality?"
#
# 4. **Share Personal Experiences**: Instead of directly challenging their beliefs, share your own experiences or observations that highlight the discrepancy in a personal way. This can make the conversation feel less confrontational.
#
# 5. **Introduce Evidence Gently**: Present evidence or facts in a non-threatening manner. You can frame it as "I found this information interesting; what do you think about it?" This way, it appears more like sharing rather than arguing.
#
# 6. **Focus on Common Goals**: Identify shared values or concerns and steer the conversation towards those. This can create common ground and make the discussion feel collaborative rather than oppositional.
#
# 7. **Encourage Exploration**: Suggest exploring the topic further together. Propose reading articles, watching documentaries, or attending lectures to gather more information. This can shift the focus from a debate to a shared quest for understanding.
#
# 8. **Practice Patience and Respect**: Recognize that changing deeply held beliefs takes time. Be patient and consistently approach the conversation with respect for their perspective, even if you disagree.
#
# 9. **Be Open to Learning**: Display your own willingness to consider other viewpoints and learn, which can encourage reciprocation. Acknowledging what you find valuable in their perspective can foster a more open dialogue.
#
# 10. **Know When to Step Back**: If the conversation becomes too heated or unproductive, it might be best to pause and revisit the topic later. Maintaining a positive relationship is often more important than winning an argument.
#
# By using these techniques, you can facilitate a constructive dialogue that encourages critical thinking and allows for a more respectful exchange of differing viewpoints.
#
# # Response from competitor 2
#
# Engaging someone with deeply held beliefs that contradict observable facts is a delicate process. It's less about directly changing their mind and more about planting seeds of doubt and encouraging self-reflection. Here's a breakdown of strategies:
#
# **1. Building Rapport and Establishing Trust:**
#
# *   **Listen empathetically:**  Before challenging anything, genuinely listen to their perspective. Understand the *why* behind their belief. Ask open-ended questions like, "What led you to believe this?" or "How has this belief shaped your life?"  Show you are interested in *understanding* them, not just *correcting* them.
# *   **Find common ground:**  Identify areas of agreement, even if they're tangential.  For example, if someone believes in a conspiracy theory about a specific government agency, you might agree that government transparency is important. Building on shared values creates a foundation for dialogue.
# *   **Use a calm and respectful tone:**  Avoid sarcasm, condescension, or aggressive language.  Your goal is to engage in a conversation, not win an argument.  Mirror their communication style to a degree to establish rapport.
# *   **Acknowledge their intelligence and sincerity:**  Even if you disagree, avoid implying they are stupid or malicious. Say things like, "I understand you've put a lot of thought into this," or "I appreciate you sharing your perspective."
#
# **2.  Gentle Questioning and Promoting Self-Reflection:**
#
# *   **Socratic questioning:**  Instead of directly contradicting their beliefs, ask questions that encourage them to think critically about their own reasoning.  Focus on the *process* of their thinking, not just the *conclusion*.  Examples:
#     *   "What evidence do you find most convincing?"
#     *   "How did you come to believe this?"
#     *   "What would it take for you to reconsider your position?"
#     *   "Are there any alternative explanations for this?"
#     *   "How reliable do you consider your sources to be?"
# *   **Highlight inconsistencies within their own belief system:**  Sometimes, people hold beliefs that contradict each other. Gently point out these inconsistencies by asking clarifying questions.  Avoid saying "You're contradicting yourself!" Instead, try, "I'm a little confused, could you help me understand how these two ideas fit together?"
# *   **Focus on verifiable facts, not opinions:**  Instead of debating subjective interpretations, direct the conversation to facts that are easily verifiable.  For example, if someone denies climate change, you could discuss objectively measured temperature increases and rising sea levels.
# *   **Use "I" statements:**  Frame your concerns as personal perspectives rather than universal truths.  For example, instead of saying "That's wrong," try "I've always understood it differently.  I've read that..."  This reduces defensiveness.
# *   **Present alternative perspectives indirectly:**  Instead of saying, "Here's why you're wrong," you could say, "I was reading an article the other day that presented a different viewpoint. It said..."
# *   **Highlight the potential consequences of holding the belief:**  Gently explore the practical implications of their belief.  For example, "How does this belief affect your decision-making in [relevant area]?" or "Are there any downsides to holding this belief?"
#
# **3.  Providing Information and Resources Carefully:**
#
# *   **Offer information neutrally:**  Instead of lecturing, provide resources (articles, studies, reputable websites) without explicitly endorsing them.  Let them come to their own conclusions.  "I came across this article the other day that you might find interesting."
# *   **Focus on the source's credibility:**  If you're sharing information, emphasize the source's reputation for accuracy and impartiality. Explain why the source is considered trustworthy. Avoid sources known for bias or conspiracy theories.
# *   **Be prepared to be wrong:**  Be open to the possibility that *you* might be mistaken.  This shows humility and encourages reciprocal open-mindedness.  "I might be misunderstanding this. Can you explain...?"
#
# **4.  Managing Expectations and Avoiding Confrontation:**
#
# *   **Don't expect immediate change:**  Changing deeply held beliefs takes time and often requires a significant emotional shift.  Your goal is to plant seeds, not perform surgery.
# *   **Accept that you may not change their mind:**  Sometimes, people are simply unwilling to change their perspective.  That's okay.  Focus on maintaining a respectful relationship.
# *   **Know when to disengage:**  If the conversation becomes heated or unproductive, politely disengage.  "I appreciate you sharing your thoughts.  Maybe we can revisit this another time."  It's better to end the conversation amicably than to damage the relationship.
# *   **Focus on the process, not the outcome:**  The goal is to encourage critical thinking, not necessarily to win the argument.  Even if they don't change their mind, you may have encouraged them to think more critically about their beliefs in the future.
#
# **Important Considerations:**
#
# *   **Motivation:**  Why do you want to engage this person? Is it truly to help them, or to prove them wrong? Your motivation will influence your approach and their receptiveness.
# *   **The topic:** Some topics are more sensitive than others (politics, religion).  Approach these with extra caution and sensitivity.
# *   **The relationship:** The closer your relationship, the more leeway you have, but also the more potential for damaging the relationship.
# *   **Their personality:**  Some people are more open to new ideas than others.  Adapt your approach accordingly.
#
# By focusing on empathy, gentle questioning, and providing information in a neutral way, you can encourage critical thinking without resorting to confrontation or dismissiveness, while still respecting their perspective.  It's a long game, and success is measured in small steps.
#
#
# # Response from competitor 3
#
# Engaging someone whose belief system is rooted deeply against empirical evidence presents both challenges and opportunities for encouraging open-mindedness. Here’s an approach that balances respect with the goal of fostering healthy skepticism:
#
# 1. **Listen Attentively**: Demonstrate genuine interest in understanding where they are coming from, without judgment or interruption.
#
# 2. **Ask Open-Ended Questions**: Encourage them to elaborate on their beliefs by asking questions like “What leads you to this conclusion?” This can help others articulate reasons that might be flawed and open up discussions about the basis of those conclusions.
#
#
# 3. **Seek Common Ground**: Identify any aspects within which there may already exist commonality, even if only partially shared values or observations.
#
# 4. **Encourage Questioning Their Own Arguments (Socratic Method)**: Invite them to consider questions that naturally arise from their assertions; this method is non-confrontational and guides someone toward self-reflection.
#
#
# 5. **Present Alternative Explanations**: If there's a basis in observable facts, gently introduce the other side of evidence using language that's inclusive rather than dismissive (“It's interesting you see it like this — have I shared something new that might explain differently?”).
#
# 6. **Focus on Empathy and Shared Experience (Narrative Persuasion)**: Humans are naturally drawn to narratives; sharing stories from a scientific perspective can make concepts more relatable, helping bridge the gap without being confrontational.
#
# 7. **Reinforce Positive Interactions**: When they express curiosity or willingness for discussion in any direction that isn’t combative and dismissive already — even if still holding contradictory beliefs somewhere else – reinforce this behavior with positive feedback.
#
#
# 8. **Be Patient (Time Factor)**: Recognize learning, especially involving deeply-held convictions against empirical evidence is a process; change rarely happens overnight.
#
# 9. **Maintain Open-Ended Dialogue**: Avoid ending conversations abruptly or making definitive assessments of their character based on belief divergence—keep the lines open for further discussion.
#
#
# 10. **Consider Their Motivations and Worldview (Relational Empathy)**: Understand that beyond contradicting facts, there can be complex reasons why someone adheres to certain beliefs; acknowledging this complexity helps maintain respectful communication even when disagreements arise.
#
# Remember it's often not about 'changing someone's mind' but rather cultivating an environment where ideas are openly exchanged with respect for individual thought processes and personal boundaries.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="o3-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["2", "1", "3"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# ['gpt-4o-mini', 'gemini-2.0-flash', 'phi4-mini']
# Rank 1: gemini-2.0-flash
# Rank 2: gpt-4o-mini
# Rank 3: phi4-mini

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
